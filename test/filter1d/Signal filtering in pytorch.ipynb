# %% [markdown]
# # Signal filtering in PyTorch
#
# ## Exercise of 1d filtering
# In this exercise, you will try to combine your theoritical knowlegde on filtering with the application of PyTorch. Specifically, we consider a sin with noise:
#
# $$y = \sin(x)+\epsilon$$
#
# in which $\epsilon$ is a small zero-center white noise. In python it can be implemented as follow:

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn.functional as F

N = 1024
x = np.linspace(0,2*np.pi,N)
signal = np.sin(x)+np.random.rand(N)*0.5

# %% [markdown]
# Now you can try to filter this noise signal in PyTorch.
#
# - Tensor structure: you can learn a lot from [a beginner tutorial](https://pytorch.org/tutorials/beginner/blitz/tensor_tutorial.html#sphx-glr-beginner-blitz-tensor-tutorial-py) and  [the official document](https://pytorch.org/docs/stable/tensors.html)
# - Convolution operation: [visualizing convolution](https://github.com/vdumoulin/conv_arithmetic) and [the official documents](https://pytorch.org/docs/stable/nn.html#torch-nn-functional)

# %%
## TODO

# gaussian_filter = ....
# box_filter = ....
# box_filtered_signal = F.conv1d(signal,box_filter)

## Optional
# gaussian_filtered_signal = F.conv1d(signal,gaussian_filter)

# %%
# Plot the original signal and filtered signal
plt.plot(signal)
# plt.plot(box_filtered_signal)
plt.show()

# %% [markdown]
# You are expected to see the following result:
# <img src="expected_result.png">
